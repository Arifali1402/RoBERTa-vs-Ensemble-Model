# %% [markdown]
# ## RoBERTa VS Base Models VS Ensemble Model

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Model names and their accuracies
models = ["RoBERTa", "SVM", "Naive Bayes", "XGBoost", "LSTM", "Custom Transformer", "Ensemble Model"]
accuracies = [82, 93.93, 73.02, 86.5, 44.62, 95.57, 98.34]

# Define colors (highlight ensemble model in different color)
colors = ["gray", "gray", "gray", "gray", "gray", "gray", "red"]

# Set up figure size
plt.figure(figsize=(10, 6))
sns.barplot(x=models, y=accuracies, palette=colors)

# Add accuracy values on top of bars
for i, acc in enumerate(accuracies):
    plt.text(i, acc + 1, f"{acc:.2f}%", ha='center', fontsize=12, fontweight='bold')

# Labels and title
plt.xlabel("Models", fontsize=14)
plt.ylabel("Accuracy (%)", fontsize=14)
plt.title("Comparison of Model Accuracies", fontsize=16)

# Add index for Ensemble Model at the bottom center
ensemble_text = "Ensemble Model uses:\nSVM, Naive Bayes, XGBoost, LSTM, Custom Transformer"

plt.text(
    3,  # X-coordinate (middle of the graph)
    -40,  # Y-coordinate (below the lowest accuracy value)
    ensemble_text,
    fontsize=12,
    bbox=dict(facecolor='white', alpha=0.5),
    ha='center'  # Center alignment
)

# Rotate x-axis labels for better readability
plt.xticks(rotation=30)

# Show grid and plot
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# <ipython-input-15-ee8ad0001b65>:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=models, y=accuracies, palette=colors)

# %% [markdown]
# ## Comparison of outputs from RoBERTa, Base Models, Ensemble Model

# %%
import pandas as pd

# Load the dataset
file_path = "twitter_validation.csv"
df = pd.read_csv(file_path)

# Check unique values in the label column
unique_values = df['label'].unique()

# Define label mapping (if necessary, modify based on actual values)
label_keys = {"Negative": "Negative", "Neutral": "Neutral", "Positive": "Positive"}

# Count occurrences of each label
label_counts = df['label'].value_counts().to_dict()

# Print results
for key in ["Negative", "Neutral", "Positive"]:
    count = label_counts.get(key, 0)
    print(f"{key}: {count}")
# Out:
# Negative: 266
# Neutral: 0
# Positive: 277

# %%
import pandas as pd

# Load the dataset
file_path = "predicted_tweets_svm.csv"
df = pd.read_csv(file_path)

# Check unique values in sentiments column
unique_values = df['sentiments'].unique()

# Adjust keys if -1 is missing but 2 is present
sentiment_keys = {-1: "Negative", 0: "Neutral", 1: "Positive"}
if -1 not in unique_values and 2 in unique_values:
    sentiment_keys = {2: "Negative", 0: "Neutral", 1: "Positive"}

# Count occurrences of each sentiment
sentiment_counts = df['sentiments'].value_counts().to_dict()

print("CSV Output Count after SVM")
# Print results with adjusted keys
for key, label in sentiment_keys.items():
    count = sentiment_counts.get(key, 0)
    print(f"{label}: {count}")
# Out:
# CSV Output Count after SVM
# Negative: 67
# Neutral: 223
# Positive: 290

# %%
import pandas as pd

# Load the dataset
file_path = "predicted_tweets_xgb.csv"
df = pd.read_csv(file_path)

# Check unique values in sentiments column
unique_values = df['sentiments'].unique()

# Adjust keys if -1 is missing but 2 is present
sentiment_keys = {-1: "Negative", 0: "Neutral", 1: "Positive"}
if -1 not in unique_values and 2 in unique_values:
    sentiment_keys = {2: "Negative", 0: "Neutral", 1: "Positive"}

# Count occurrences of each sentiment
sentiment_counts = df['sentiments'].value_counts().to_dict()

print("CSV Output Count after XGboost")
# Print results with adjusted keys
for key, label in sentiment_keys.items():
    count = sentiment_counts.get(key, 0)
    print(f"{label}: {count}")
# Out:
# CSV Output Count after XGboost
# Negative: 236
# Neutral: 44
# Positive: 300

# %%
import pandas as pd

# Load the dataset
file_path = "predicted_tweets_nb.csv"
df = pd.read_csv(file_path)

# Check unique values in sentiments column
unique_values = df['sentiments'].unique()

# Adjust keys if -1 is missing but 2 is present
sentiment_keys = {-1: "Negative", 0: "Neutral", 1: "Positive"}
if -1 not in unique_values and 2 in unique_values:
    sentiment_keys = {2: "Negative", 0: "Neutral", 1: "Positive"}

# Count occurrences of each sentiment
sentiment_counts = df['sentiments'].value_counts().to_dict()

print("CSV Output Count after Naive Bayes")
# Print results with adjusted keys
for key, label in sentiment_keys.items():
    count = sentiment_counts.get(key, 0)
    print(f"{label}: {count}")
# Out:
# CSV Output Count after Naive Bayes
# Negative: 30
# Neutral: 66
# Positive: 484

# %%
import pandas as pd

# Load the dataset
file_path = "predicted_tweets_lstm.csv"
df = pd.read_csv(file_path)

# Check unique values in sentiments column
unique_values = df['sentiments'].unique()

# Adjust keys if -1 is missing but 2 is present
sentiment_keys = {-1: "Negative", 0: "Neutral", 1: "Positive"}
if -1 not in unique_values and 2 in unique_values:
    sentiment_keys = {2: "Negative", 0: "Neutral", 1: "Positive"}

# Count occurrences of each sentiment
sentiment_counts = df['sentiments'].value_counts().to_dict()

print("CSV Output Count after LSTM")
# Print results with adjusted keys
for key, label in sentiment_keys.items():
    count = sentiment_counts.get(key, 0)
    print(f"{label}: {count}")
# Out:
# CSV Output Count after LSTM
# Negative: 0
# Neutral: 0
# Positive: 580

# %%
import pandas as pd

# Load the dataset
file_path = "predicted_tweets_ctrans.csv"
df = pd.read_csv(file_path)

# Check unique values in sentiments column
unique_values = df['Sentiments'].unique()

# Adjust keys if -1 is missing but 2 is present
sentiment_keys = {-1: "Negative", 0: "Neutral", 1: "Positive"}
if -1 not in unique_values and 2 in unique_values:
    sentiment_keys = {2: "Negative", 0: "Neutral", 1: "Positive"}

# Count occurrences of each sentiment
sentiment_counts = df['Sentiments'].value_counts().to_dict()

print("CSV Output Count after Custom Transformer")
# Print results with adjusted keys
for key, label in sentiment_keys.items():
    count = sentiment_counts.get(key, 0)
    print(f"{label}: {count}")
# Out:
# CSV Output Count after Custom Transformer
# Negative: 83
# Neutral: 183
# Positive: 314

# %%
import pandas as pd

# Load the dataset
file_path = "predicted_tweets_ensemble.csv"
df = pd.read_csv(file_path)

# Check unique values in sentiments column
unique_values = df['sentiments'].unique()

# Adjust keys if -1 is missing but 2 is present
sentiment_keys = {-1: "Negative", 0: "Neutral", 1: "Positive"}
if -1 not in unique_values and 2 in unique_values:
    sentiment_keys = {2: "Negative", 0: "Neutral", 1: "Positive"}

# Count occurrences of each sentiment
sentiment_counts = df['sentiments'].value_counts().to_dict()

print("CSV Output Count after Ensemble Model")
# Print results with adjusted keys
for key, label in sentiment_keys.items():
    count = sentiment_counts.get(key, 0)
    print(f"{label}: {count}")
# Out:
# CSV Output Count after Ensemble Model
# Negative: 78
# Neutral: 203
# Positive: 294

# %%
import matplotlib.pyplot as plt
import numpy as np

# Models
models = ["RoBERTa", "SVM", "XGBoost", "Naive Bayes", "LSTM", "Custom Transformer", "Ensemble Model"]

# Sentiment counts
negative_counts = [266, 67, 236, 30, 0, 83, 78]
neutral_counts = [0, 223, 44, 66, 0, 183, 203]
positive_counts = [277, 290, 300, 484, 580, 314, 294]

# Set up bar width and positions
x = np.arange(len(models))
width = 0.25

# Create grouped bar chart
fig, ax = plt.subplots(figsize=(12, 6))
bars1 = ax.bar(x - width, negative_counts, width, label="Negative", color="red")
bars2 = ax.bar(x, neutral_counts, width, label="Neutral", color="gray")
bars3 = ax.bar(x + width, positive_counts, width, label="Positive", color="green")

# Labels and title
ax.set_xlabel("Models", fontsize=12)
ax.set_ylabel("Count", fontsize=12)
ax.set_title("Sentiment Distribution Across Models", fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(models, rotation=30, ha="right")
ax.legend()

# Display values on top of bars
for bars in [bars1, bars2, bars3]:
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f"{height}", xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords="offset points",
                    ha="center", fontsize=10)

# Show plot
plt.tight_layout()
plt.show()
